# %%
import urllib.request
import urllib.parse
import json
import time
import gzip

# %% [markdown]
# National Archives explains the following:
#
# For example, if you would like to construct a very specific search across all series for records with a "Top Secret" security classification, and the term "Army" in the description's title:
#
# https://catalog.archives.gov/api/v1/?description.series.accessRestriction.specificAccessRestrictionArray.specificAccessRestriction.securityClassification.termName=top%20secret&description.series.title=army

# %%
my_fields = ['naId', 'scopeAndContentNote', 'title', 'recordHistory', 
             'physicalOccurrenceArray', 'localIdentifier',
             'variantControlNumberArray']

def record_yielder(step = 20, skip = 0, start_with = None):
    """
    Using the national Archives 
    """
    cursorMark = '*'
    completed = 0

    if start_with is not None:
        # Allow picking up from a certain point.
        cursorMark = [g.replace("cursorMark=", "") for g in start_with.split("&") if g.startswith("cursorMark")][0]
        completed = int(cursorMark.split("-")[-1])
    
    url = "https://catalog.archives.gov/api/v1/?"
    # I have determined that I only care about these fields--especially 'scopeAndContentNote'

    values = {
        'description.fileUnit.parentSeries.naId': '4488912', 
        "cursorMark": cursorMark,
        "rows": str(step)
    }
    not_done_yet = True
    round = 1
    while not_done_yet:
        data = urllib.parse.urlencode(values)
        my_fields_detailed_path = ["description.fileUnit." + f for f in my_fields]
        
        fast_forward = completed + step < skip
        if fast_forward:
            # As described in the API documentation
            my_fields_detailed_path = ["num"]
            
        data = data + "&resultFields=" + ",".join(my_fields_detailed_path)
        print(url + data)
        try:
            with urllib.request.urlopen(url + data) as response:
                page = json.loads(response.read())
        except urllib.error.HTTPError as e:
            ResponseData = e.read().decode("utf8", 'ignore')
            print(ResponseData)
            raise

        completed += step
        results = page['opaResponse']['results']['result']
        for record in results:
            if not fast_forward:
                yield record
        round += 1
        # NARA doesn't specify their rate limits.
        time.sleep(2)
        values['cursorMark'] = page['opaResponse']['results']['nextCursorMark']
        not_done_yet = page['opaResponse']['results']['total'] > page['opaResponse']['results']['offset'] + page['opaResponse']['results']['rows']

# %%
urllib.error.HTTPError
# Out:
# urllib.error.HTTPError

# %%
def parse_record(record):
    record_information = {}
    description = record['description']['fileUnit']
    for key in my_fields:
        record_information[key] = description[key]
    return record_information

# %%
with gzip.open("all_records_4488912.txt.gz", "at") as fout:
    for record in record_yielder(3000, skip = 581000):
        fout.write(json.dumps(record) + "\n")
# Out:
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=%2A&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjavIDW8gIuZGVzYy0xNTg1NTA5MjA%3D-3000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHi6nYDW8gIuZGVzYy0xNTg1NDgwMDU%3D-6000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHid%2Ff%2FV8gIuZGVzYy0xNTg1NDQ5NDU%3D-9000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiM2f%2FV8gIuZGVzYy0xNTg1NDE5NjA%3D-12000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjyt%2F%2FV8gIuZGVzYy0xNTg1Mzg5Mjg%3D-15000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjhk%2F%2FV8gIuZGVzYy0xNTg1MzU5MzI%3D-18000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCG8%2F7V8gIuZGVzYy0xNTg1MzI5MzM%3D-21000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDs0f7V8gIuZGVzYy0xNTg1Mjk5NTM%3D-24000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiWr%2F7V8gIuZGVzYy0xNTg1MjY5NDk%3D-27000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHC%2Bjf7V8gIuZGVzYy0xNTg1MjM5NDI%3D-30000&rows=3000&resultFields=num
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAH
&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDfma6B8QIsZGVzYy01NDY5ODU0-1080000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHju%2F62B8QIsZGVzYy01NDY3MTU0-1083000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHD%2B5a2B8QIsZGVzYy01NDY0NDQy-1086000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDMzK2B8QIsZGVzYy01NDYxNzA0-1089000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCsra2B8QIsZGVzYy01MTg5ODk1-1092000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiosOb%2B8AIsZGVzYy01NDU3NzYx-1095000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDWjOb%2B8AIsZGVzYy01NDU1MDQ3-1098000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDF6OX%2B8AIsZGVzYy01NDUyMzEw-1101000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHC0xOX%2B8AIsZGVzYy01NDQ3Njkz-1104000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCjoOX%2B8AIsZGVzYy01NDQ0OTMx-1107000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjT%2B%2BT%2B8AIsZGVzYy01NDQxNzM4-1110000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCE1%2BT%2B8AIsZGVzYy01NDM4OTky-1113000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHi9r%2BT%2B8AIsZGVzYy01NDM2MjE0-1116000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiviuT%2B8AIsZGVzYy01MTg0Mzk0-1119000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDj5OP%2B8AIsZGVzYy01MTgxMzE2-1122000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiQweP%2B8AIsZGVzYy01MTc4Mzc1-1125000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiCnOP%2B8AIsZGVzYy01MTc1MzUx-1128000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCEj8mV7wItZGVzYy00MDA3OTkzNg%3D%3D-1131000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHD67I%2BV7wItZGVzYy00MDA3Njg0NA%3D%3D-1134000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDF1I%2BV7wItZGVzYy00MDA3Mzg1Nw%3D%3D-1137000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHCTu4%2BV7wItZGVzYy00MDA3MDg5Mg%3D%3D-1140000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDwnI%2BV7wItZGVzYy00MDA2NzkzMw%3D%3D-1143000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHC7hI%2BV7wItZGVzYy00MDA2NDkwNg%3D%3D-1146000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjH646V7wItZGVzYy00MDA2MTg1NQ%3D%3D-1149000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHDX0Y6V7wItZGVzYy00MDA1ODg0Ng%3D%3D-1152000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjmt46V7wItZGVzYy00MDA1NTc5Nw%3D%3D-1155000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHixn46V7wItZGVzYy00MDA1MjgyMg%3D%3D-1158000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHj8ho6V7wItZGVzYy00MDA0OTgyNQ%3D%3D-1161000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjH7o2V7wItZGVzYy00MDA0NjgwNg%3D%3D-1164000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHiS1o2V7wItZGVzYy00MDA0MzgzNw%3D%3D-1167000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# https://catalog.archives.gov/api/v1/?description.fileUnit.parentSeries.naId=4488912&cursorMark=AoMIP4AAAHjdvY2V7wItZGVzYy00MDA0MDgwMg%3D%3D-1170000&rows=3000&resultFields=description.fileUnit.naId,description.fileUnit.scopeAndContentNote,description.fileUnit.title,description.fileUnit.recordHistory,description.fileUnit.physicalOccurrenceArray,description.fileUnit.localIdentifier,description.fileUnit.variantControlNumberArray
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-453a2f25a1e5> in <module>
#       1 with gzip.open("all_records_4488912.txt.gz", "at") as fout:
# ----> 2     for record in record_yielder(3000, skip = 581000):
#       3         fout.write(json.dumps(record) + "\n")
#
# <ipython-input-2-e931d3a67fb1> in record_yielder(step, skip, start_with)
#      52         # NARA doesn't specify their rate limits.
#      53         time.sleep(2)
# ---> 54         values['cursorMark'] = page['opaResponse']['results']['nextCursorMark']
#      55         not_done_yet = page['opaResponse']['results']['total'] > page['opaResponse']['results']['offset'] + page['opaResponse']['results']['rows']
#
# KeyError: 'nextCursorMark'
